# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def cargar_y_visualizar_datos_desde_csv(archivo_csv):
    try:
        # Cargar datos desde el archivo CSV
        datos = pd.read_csv(archivo_csv)

        # Mostrar una vista previa de los datos y nombres de columnas
        print("Vista previa de los datos:")
        print(datos.head())

        print("\nNombres de columnas:")
        print(datos.columns)

        # Eliminar espacios en blanco alrededor de los nombres de las columnas
        datos.columns = datos.columns.str.strip()

        # Verificar la existencia de la columna 'tipo_producto'
        if 'tipo_producto' not in datos.columns:
            raise ValueError("La columna 'tipo_producto' no está presente en los datos.")

        # Verificar la existencia de la columna 'monto_total'
        if 'monto_total' not in datos.columns:
            raise ValueError("La columna 'monto_total' no está presente en los datos.")
        else:
            # Verificar el tipo de datos en la columna 'monto_total'
            print("Tipo de datos en la columna 'monto_total':", datos['monto_total'].dtype)

            # Asegurar que la columna 'monto_total' sea de tipo numérico
            datos['monto_total'] = pd.to_numeric(datos['monto_total'], errors='coerce')

            # Visualizar gráficos de estadísticas (ejemplo con seaborn)
            sns.set(style="whitegrid")
            plt.figure(figsize=(10, 6))

            # Ajustar el nombre de la columna según tus datos
            sns.barplot(x='tipo_producto', y='monto_total', data=datos)

            # Ajustar el título y etiquetas del eje X e Y según tus necesidades
            plt.title('Gráfico de Ventas por Tipos de Producto')
            plt.xlabel('Tipos de Producto')
            plt.ylabel('Ventas')

            # Ajustar el diseño para evitar solapamiento de etiquetas en el eje X
            plt.xticks(rotation=45, ha='right')

            # Mostrar el gráfico
            plt.show()

    except Exception as e:
        print(f"Error al cargar o procesar los datos: {str(e)}")

# Ejecución
archivo_csv = '/content/dataset (2).csv'
cargar_y_visualizar_datos_desde_csv(archivo_csv)
# Out:
# Vista previa de los datos:
#             ruc             razon_social  cliekey tipo_cliente tipo_documento  \
# 0  525711518I-8        Banco Atlas SAECA     3987            F            RUC
# 1  680883860J-3       Vision Banco SAECA     2844            F      Pasaporte
# 2  874607880N-7  Banco Continental SAECA     5253            J      Pasaporte
# 3  392958030J-4        Banco Atlas SAECA     5823            J             CI
# 4  395092238H-7        Banco Atlas SAECA     3851            F             CI
#
#    nro_documento  cod_producto  cant_venta  tipo_producto  precio_unitario  \
# 0       91736507            43           8              2            35000
# 1       92856177            41           4              4            96000
# 2       37113748            48           7              4            34000
# 3       31564627            55           9              2             4000
# 4       75339032            61           7              3            86000
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def cargar_y_visualizar_datos_desde_csv(archivo_csv):
    try:
        # Cargar datos desde el archivo CSV
        datos = pd.read_csv(archivo_csv)

        # Mostrar una vista previa de los datos y nombres de columnas
        print("Vista previa de los datos:")
        print(datos.head())

        print("\nNombres de columnas:")
        print(datos.columns)

        # Eliminar espacios en blanco alrededor de los nombres de las columnas
        datos.columns = datos.columns.str.strip()

        # Verificar la existencia de la columna 'tipo_producto'
        if 'tipo_producto' not in datos.columns:
            raise ValueError("La columna 'tipo_producto' no está presente en los datos.")

        # Verificar la existencia de la columna 'monto_total'
        if 'monto_total' not in datos.columns:
            raise ValueError("La columna 'monto_total' no está presente en los datos.")
        else:
            # Verificar el tipo de datos en la columna 'monto_total'
            print("Tipo de datos en la columna 'monto_total':", datos['monto_total'].dtype)

            # Asegurar que la columna 'monto_total' sea de tipo numérico
            datos['monto_total'] = pd.to_numeric(datos['monto_total'], errors='coerce')

            # Visualizar gráficos de estadísticas (ejemplo con seaborn)
            sns.set(style="whitegrid")
            plt.figure(figsize=(15, 6))

            # Gráfico de barras por tipo de producto
            plt.subplot(1, 2, 1)
            sns.barplot(x='tipo_producto', y='monto_total', data=datos)
            plt.title('Gráfico de Ventas por Tipos de Producto')
            plt.xlabel('Tipos de Producto')
            plt.ylabel('Ventas')

            # Gráfico de torta por tipo de producto
            plt.subplot(1, 2, 2)
            ventas_por_tipo = datos.groupby('tipo_producto')['monto_total'].sum()
            plt.pie(ventas_por_tipo, labels=ventas_por_tipo.index, autopct='%1.1f%%', startangle=90)
            plt.title('Gráfico de Torta de Ventas por Tipos de Producto')

            # Ajustar el diseño general
            plt.tight_layout()

            # Mostrar los gráficos
            plt.show()

    except Exception as e:
        print(f"Error al cargar o procesar los datos: {str(e)}")

# Ejecución
archivo_csv = '/content/dataset (2).csv'
cargar_y_visualizar_datos_desde_csv(archivo_csv)
# Out:
# Vista previa de los datos:
#             ruc             razon_social  cliekey tipo_cliente tipo_documento  \
# 0  525711518I-8        Banco Atlas SAECA     3987            F            RUC
# 1  680883860J-3       Vision Banco SAECA     2844            F      Pasaporte
# 2  874607880N-7  Banco Continental SAECA     5253            J      Pasaporte
# 3  392958030J-4        Banco Atlas SAECA     5823            J             CI
# 4  395092238H-7        Banco Atlas SAECA     3851            F             CI
#
#    nro_documento  cod_producto  cant_venta  tipo_producto  precio_unitario  \
# 0       91736507            43           8              2            35000
# 1       92856177            41           4              4            96000
# 2       37113748            48           7              4            34000
# 3       31564627            55           9              2             4000
# 4       75339032            61           7              3            86000
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def cargar_y_visualizar_datos_desde_csv(archivo_csv):
    try:
        # Cargar datos desde el archivo CSV
        datos = pd.read_csv(archivo_csv)

        # Mostrar una vista previa de los datos y nombres de columnas
        print("Vista previa de los datos:")
        print(datos.head())

        print("\nNombres de columnas:")
        print(datos.columns)

        # Eliminar espacios en blanco alrededor de los nombres de las columnas
        datos.columns = datos.columns.str.strip()

        # Verificar la existencia de la columna 'tipo_producto'
        if 'tipo_producto' not in datos.columns:
            raise ValueError("La columna 'tipo_producto' no está presente en los datos.")

        # Verificar la existencia de la columna 'monto_total'
        if 'monto_total' not in datos.columns:
            raise ValueError("La columna 'monto_total' no está presente en los datos.")
        else:
            # Verificar el tipo de datos en la columna 'monto_total'
            print("Tipo de datos en la columna 'monto_total':", datos['monto_total'].dtype)

            # Asegurar que la columna 'monto_total' sea de tipo numérico
            datos['monto_total'] = pd.to_numeric(datos['monto_total'], errors='coerce')

            # Visualizar gráficos de estadísticas (ejemplo con seaborn)
            sns.set(style="whitegrid")
            plt.figure(figsize=(18, 12))

            # Gráfico de barras por tipo de producto
            plt.subplot(2, 2, 1)
            sns.barplot(x='tipo_producto', y='monto_total', data=datos)
            plt.title('Gráfico de Ventas por Tipos de Producto')
            plt.xlabel('Tipos de Producto')
            plt.ylabel('Ventas')

            # Gráfico de torta por tipo de producto
            plt.subplot(2, 2, 2)
            ventas_por_tipo = datos.groupby('tipo_producto')['monto_total'].sum()
            plt.pie(ventas_por_tipo, labels=ventas_por_tipo.index, autopct='%1.1f%%', startangle=90)
            plt.title('Gráfico de Torta de Ventas por Tipos de Producto')

            # Gráfico de línea de ventas acumuladas por fecha de venta
            plt.subplot(2, 1, 2)
            datos['fecha_venta'] = pd.to_datetime(datos['fecha_venta'])
            ventas_acumuladas = datos.groupby('fecha_venta')['monto_total'].sum().cumsum()
            plt.plot(ventas_acumuladas.index, ventas_acumuladas, marker='o', linestyle='-', color='b')
            plt.title('Gráfico de Ventas Acumuladas por Fecha de Venta')
            plt.xlabel('Fecha de Venta')
            plt.ylabel('Ventas Acumuladas')

            # Ajustar el diseño general
            plt.tight_layout()

            # Mostrar los gráficos
            plt.show()

    except Exception as e:
        print(f"Error al cargar o procesar los datos: {str(e)}")

# Ejecución
archivo_csv = '/content/dataset (2).csv'
cargar_y_visualizar_datos_desde_csv(archivo_csv)
# Out:
# Vista previa de los datos:
#             ruc             razon_social  cliekey tipo_cliente tipo_documento  \
# 0  525711518I-8        Banco Atlas SAECA     3987            F            RUC
# 1  680883860J-3       Vision Banco SAECA     2844            F      Pasaporte
# 2  874607880N-7  Banco Continental SAECA     5253            J      Pasaporte
# 3  392958030J-4        Banco Atlas SAECA     5823            J             CI
# 4  395092238H-7        Banco Atlas SAECA     3851            F             CI
#
#    nro_documento  cod_producto  cant_venta  tipo_producto  precio_unitario  \
# 0       91736507            43           8              2            35000
# 1       92856177            41           4              4            96000
# 2       37113748            48           7              4            34000
# 3       31564627            55           9              2             4000
# 4       75339032            61           7              3            86000
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def cargar_y_visualizar_datos_desde_csv(archivo_csv):
    try:
        # Cargar datos desde el archivo CSV
        datos = pd.read_csv(archivo_csv)

        # Mostrar una vista previa de los datos y nombres de columnas
        print("Vista previa de los datos:")
        print(datos.head())

        print("\nNombres de columnas:")
        print(datos.columns)

        # Eliminar espacios en blanco alrededor de los nombres de las columnas
        datos.columns = datos.columns.str.strip()

        # Verificar la existencia de la columna 'tipo_producto'
        if 'tipo_producto' not in datos.columns:
            raise ValueError("La columna 'tipo_producto' no está presente en los datos.")

        # Verificar la existencia de la columna 'monto_total'
        if 'monto_total' not in datos.columns:
            raise ValueError("La columna 'monto_total' no está presente en los datos.")
        else:
            # Verificar el tipo de datos en la columna 'monto_total'
            print("Tipo de datos en la columna 'monto_total':", datos['monto_total'].dtype)

            # Asegurar que la columna 'monto_total' sea de tipo numérico
            datos['monto_total'] = pd.to_numeric(datos['monto_total'], errors='coerce')

            # Visualizar gráficos de estadísticas (ejemplo con seaborn)
            sns.set(style="whitegrid")
            plt.figure(figsize=(18, 12))

            # Gráfico de barras por tipo de producto
            plt.subplot(2, 2, 1)
            sns.barplot(x='tipo_producto', y='monto_total', data=datos)
            plt.title('Gráfico de Ventas por Tipos de Producto')
            plt.xlabel('Tipos de Producto')
            plt.ylabel('Ventas')

            # Gráfico de torta por tipo de producto
            plt.subplot(2, 2, 2)
            ventas_por_tipo = datos.groupby('tipo_producto')['monto_total'].sum()
            plt.pie(ventas_por_tipo, labels=ventas_por_tipo.index, autopct='%1.1f%%', startangle=90)
            plt.title('Gráfico de Torta de Ventas por Tipos de Producto')

            # Gráfico de línea de ventas acumuladas por fecha de venta
            plt.subplot(2, 2, 3)
            datos['fecha_venta'] = pd.to_datetime(datos['fecha_venta'])
            ventas_acumuladas = datos.groupby('fecha_venta')['monto_total'].sum().cumsum()
            plt.plot(ventas_acumuladas.index, ventas_acumuladas, marker='o', linestyle='-', color='b')
            plt.title('Gráfico de Ventas Acumuladas por Fecha de Venta')
            plt.xlabel('Fecha de Venta')
            plt.ylabel('Ventas Acumuladas')

            # Gráfico de barras horizontales de los 10 importes de venta más altos
            plt.subplot(2, 2, 4)
            top_10_ventas = datos.nlargest(10, 'monto_total')
            sns.barplot(x='monto_total', y='fecha_venta', data=top_10_ventas)  # Eliminado 'hue' ya que 'cliente' no está presente
            plt.title('Top 10 Importes de Venta por Fecha')
            plt.xlabel('Ventas')
            plt.ylabel('Fecha de Venta')

            # Ajustar el diseño general
            plt.tight_layout()

            # Mostrar los gráficos
            plt.show()

    except Exception as e:
        print(f"Error al cargar o procesar los datos: {str(e)}")

# Ejecución
archivo_csv = '/content/dataset (2).csv'
cargar_y_visualizar_datos_desde_csv(archivo_csv)
# Out:
# Vista previa de los datos:
#             ruc             razon_social  cliekey tipo_cliente tipo_documento  \
# 0  525711518I-8        Banco Atlas SAECA     3987            F            RUC
# 1  680883860J-3       Vision Banco SAECA     2844            F      Pasaporte
# 2  874607880N-7  Banco Continental SAECA     5253            J      Pasaporte
# 3  392958030J-4        Banco Atlas SAECA     5823            J             CI
# 4  395092238H-7        Banco Atlas SAECA     3851            F             CI
#
#    nro_documento  cod_producto  cant_venta  tipo_producto  precio_unitario  \
# 0       91736507            43           8              2            35000
# 1       92856177            41           4              4            96000
# 2       37113748            48           7              4            34000
# 3       31564627            55           9              2             4000
# 4       75339032            61           7              3            86000
#
# ...
